# %% [markdown]
# Probable Name: Dridex
#
# MD5: 3635ac6099baedae893b3991f730652c
#
# SHA1: cd08cc349459f99be7d00c046f6b9e5203c0f110
#
# SHA256: 326d9bf458c589d7988886d111b6933db21efc950bfa1b44b1814c9dfdcb674b
#
# Password of zip file: infected
#
# Duration: 32 days 22:58:50
#
#
# VirusTotal
# HybridAnalysis
# RobotHash

# %%
import pandas as pd

# %%
dridex = pd.read_csv(r"../../data/raw/csv/dridex.csv")

dridex.shape
# Out:
# (60247, 19)

# %% [markdown]
# ## Labelling

# %%
ip_list = ["109.74.9.119","69.43.168.214"]

# %%
dridex.loc[
    (dridex['Destination IP'].isin(ip_list)) | (dridex['Source IP'].isin(ip_list)),
    'Label'
] = 'Dridex'

dridex.fillna("Benign", inplace=True)

# %%
dridex["Label"].value_counts()
# Out:
# Label
# Benign    30130
# Dridex    30117
# Name: count, dtype: int64

# %% [markdown]
# ## Flag Formatting

# %%
# List of TCP flags
tcp_flag_mapping = [
    'FIN',
    'SYN',
    'RST',
    'PSH',
    'ACK',
    'URG',
    'ECE',
    'CWR',
    'NS',
]

# Function to format the flags
def format_flags(flags_str):
    # Capitalize the flags string first
    flags_str = flags_str.upper()

    # Initialize an empty list to store found flags
    formatted_flags = []

    # Check each individual flag from the mapping
    for flag in tcp_flag_mapping:
        if flag in flags_str:
            formatted_flags.append(flag)

    # Join the found flags with commas
    return ','.join(formatted_flags)

# Apply the format_flags function to the "flags" column
dridex['Flags'] = dridex['Flags'].apply(format_flags)

# %%
dridex
# Out:
#        Duration        Source IP   Destination IP  Source Port  \
# 0      0.000000  216.218.185.162    192.168.1.110           80
# 1      0.000000    192.168.1.110  216.218.185.162        49194
# 2      8.473776    192.168.1.110   203.153.165.21        49191
# 3      8.473635   203.153.165.21    192.168.1.110         8343
# 4      4.833665    192.168.1.110   203.153.165.21        49191
# ...         ...              ...              ...          ...
# 60242  0.016348   192.188.58.163    192.168.1.110         4431
# 60243  0.563029    192.168.1.110     109.74.9.119        64255
# 60244  0.563039     109.74.9.119    192.168.1.110         4431
# 60245  0.181608    192.168.1.110     109.74.9.119        64255
# 60246  0.396511     109.74.9.119    192.168.1.110         4431
#
#        Destination Port Protocol        Flags  Packets  Bytes  \
# 0                 49194      TCP      FIN,ACK        1     34
# 1                    80      TCP          RST        1     34
# 2                  8343      TCP  FIN,SYN,ACK        5    182
# 3                 49191      TCP  FIN,SYN,ACK        5    206
# 4                  8343      TLS      PSH,ACK        3   1233
# ...                 ...      ...          ...      ...    ...
# 60242             64254      TLS  FIN,PSH,ACK        5   2898
# 60243              4431      TCP  FIN,SYN,ACK        5    182
# 60244             64255      TCP      SYN,ACK        5    182
# 60245              4431      TLS      PSH,ACK        3   1137
# 60246             64255      TLS  FIN,PSH,ACK        5   2765
#
#        Mean Payload Size  Std Payload Size  Min Payload Size  \
# 0                   34.0          0.000000                34
# 1                   34.0          0.000000                34
# 2                   36.4          4.800000                34
# 3                   41.2          2.400000                40
# 4                  411.0        227.011013               162
# ...                  ...               ...               ...
# 60242              579.6        508.031338               103
# 60243               36.4          4.800000                34
# 60244               36.4          4.800000                34
# 60245              379.0        257.398524               194
# 60246              553.0        514.371461               125
#
#        Max Payload Size  Mean Entropy  Min Entropy  Max Entropy  \
# 0                    34      0.000000     0.000000     0.000000
# 1                    34      0.000000     0.000000     0.000000
# 2                    46      0.000000     0.000000     0.000000
# 3                    46      0.000000     0.000000     0.000000
# 4                   711      3.377385     2.987760     3.584673
# ...                 ...           ...          ...          ...
# 60242              1494      3.538817     3.487283     3.580074
# 60243                46      0.000000     0.000000     0.000000
# 60244                46      0.000000     0.000000     0.000000
# 60245               743      3.422468     3.155306     3.578610
# 60246              1494      3.534779     3.494059     3.570036
#
#        Mean Inter-Packet Interval  Min Inter-Packet Interval  \
# 0                        0.000000                   0.000000
# 1                        0.000000                   0.000000
# 2                        2.118444                   0.016947
# 3                        2.118409                   0.396701
# 4                        2.416832                   0.389016
# ...                           ...                        ...
# 60242                    0.004087                   0.000034
# 60243                    0.140757                   0.000151
# 60244                    0.140760                   0.000362
# 60245                    0.090804                   0.001789
# 60246                    0.099128                   0.000038
#
#        Max Inter-Packet Interval   Label
# 0                       0.000000  Benign
# 1                       0.000000  Benign
# 2                       7.054314  Benign
# 3                       4.874338  Benign
# 4                       4.444649  Benign
# ...                          ...     ...
# 60242                   0.014716  Benign
# 60243                   0.396414  Dridex
# 60244                   0.342231  Dridex
# 60245                   0.179819  Dridex
# 60246                   0.381397  Dridex
#
# [60247 rows x 20 columns]

# %% [markdown]
# ## Ordering Cloumns

# %% [markdown]
# ## Saving to CSV

# %%
dridex.to_csv('../../data/labelled/static/dridex_data.csv', index=False)
