# %% [markdown]
# # Emotet
# - Probably Emotet
# - MD5 8baa9b809b591a11af423824f4d9726a
# - [VirusTotal](https://www.virustotal.com/gui/file/6393fe8dd4721190f240e22feeb769675b6194a70cabd5a415c2364686a9089c/detection)
# - [Malware Link](https://mcfp.felk.cvut.cz/publicDatasets/CTU-Malware-Capture-Botnet-114-3/)

# %%
import pandas as pd

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Loading

# %%
# Define the path to your file
file_path = r"../../data/labelled/static/trickbot_static.csv"

df = pd.read_csv(file_path)
df.head()
# Out:
#     Duration      Source IP Destination IP  Source Port  Destination Port  \
# 0  10.032950  192.168.1.116  78.47.139.102        49158                80
# 1  10.032912  78.47.139.102  192.168.1.116           80             49158
# 2   0.000000  192.168.1.116  78.47.139.102        49158                80
# 3   0.000000  78.47.139.102  192.168.1.116           80             49158
# 4   8.999519  192.168.1.116    36.37.176.6        49159               443
#
#           Protocol            Flags  Packets  Bytes  Mean Payload Size  \
# 0              TCP      FIN,SYN,ACK        5    182          36.400000
# 1              TCP  FIN,SYN,RST,ACK        5    206          41.200000
# 2             HTTP          PSH,ACK        1    123         123.000000
# 3  DATA-TEXT-LINES          PSH,ACK        1    260         260.000000
# 4              TCP              SYN        3    134          44.666667
#
#    Std Payload Size  Min Payload Size  Max Payload Size  Mean Entropy  \
# 0          4.800000                34                46      0.000000
# 1          2.400000                40                46      0.000000
# 2          0.000000               123               123      3.359351
# 3          0.000000               260               260      3.323090
# 4          1.885618                42                46      0.000000
#
#    Min Entropy  Max Entropy  Mean Inter-Packet Interval  \
# 0     0.000000     0.000000                    2.508238
# 1     0.000000     0.000000                    2.508228
# 2     3.359351     3.359351                    0.000000
# 3     3.323090     3.323090                    0.000000
# 4     0.000000     0.000000                    4.499760
#
#    Min Inter-Packet Interval  Max Inter-Packet Interval     Label
# 0                   0.000134                   9.805283  trickbot
# 1                   0.016541                   9.972808  trickbot
# 2                   0.000000                   0.000000  trickbot
# 3                   0.000000                   0.000000  trickbot
# 4                   2.991381                   6.008138  trickbot

# %% [markdown]
# ### Data Balancaing

# %%
df["Label"].value_counts()

#! No need for data balancing
# Out:
# Label
# Benign      27018
# trickbot    17730
# Name: count, dtype: int64

# %% [markdown]
# ## Filling Null

# %%
df["Flags"] = df["Flags"].fillna("UNK")

# %% [markdown]
# ## Data Engineering

# %%
engineering_df = df.copy()

# %%
engineering_df
# Out:
#         Duration       Source IP  Destination IP  Source Port  \
# 0      10.032950   192.168.1.116   78.47.139.102        49158
# 1      10.032912   78.47.139.102   192.168.1.116           80
# 2       0.000000   192.168.1.116   78.47.139.102        49158
# 3       0.000000   78.47.139.102   192.168.1.116           80
# 4       8.999519   192.168.1.116     36.37.176.6        49159
# ...          ...             ...             ...          ...
# 44743  19.103234  190.138.249.45   192.168.1.116          443
# 44744   2.913438   192.168.1.116  190.138.249.45        60420
# 44745   1.921156  190.138.249.45   192.168.1.116          443
# 44746   1.883389   192.168.1.116  190.138.249.45        60420
# 44747   0.844718  190.138.249.45   192.168.1.116          443
#
#        Destination Port         Protocol            Flags  Packets  Bytes  \
# 0                    80              TCP      FIN,SYN,ACK        5    182
# 1                 49158              TCP  FIN,SYN,RST,ACK        5    206
# 2                    80             HTTP          PSH,ACK        1    123
# 3                 49158  DATA-TEXT-LINES          PSH,ACK        1    260
# 4                   443              TCP              SYN        3    134
# ...                 ...              ...              ...      ...    ...
# 44743             60419              TLS          PSH,ACK       14  12750
# 44744               443              TCP          SYN,ACK        5    182
# 44745             60420              TCP          SYN,ACK        4    148
# 44746               443              TLS          PSH,ACK        3    619
# 44747             60420              TLS          PSH,ACK        5   2638
#
#        Mean Payload Size  Std Payload Size  Min Payload Size  \
# 0              36.400000          4.800000                34
# 1              41.200000          2.400000                40
# 2             123.000000          0.000000               123
# 3             260.000000          0.000000               260
# 4              44.666667          1.885618                42
# ...                  ...               ...               ...
# 44743         910.714286        583.210257                93
# 44744          36.400000          4.800000                34
# 44745          37.000000          5.196152                34
# 44746         206.333333         62.887907               156
# 44747         527.600000        529.438419                93
#
#        Max Payload Size  Mean Entropy  Min Entropy  Max Entropy  \
# 0                    46      0.000000     0.000000     0.000000
# 1                    46      0.000000     0.000000     0.000000
# 2                   123      3.359351     3.359351     3.359351
# 3                   260      3.323090     3.323090     3.323090
# 4                    46      0.000000     0.000000     0.000000
# ...                 ...           ...          ...          ...
# 44743              1494      3.561511     3.470805     3.583486
# 44744                46      0.000000     0.000000     0.000000
# 44745                46      0.000000     0.000000     0.000000
# 44746               295      3.450546     3.282975     3.574163
# 44747              1494      3.532657     3.469744     3.577813
#
#        Mean Inter-Packet Interval  Min Inter-Packet Interval  \
# 0                        2.508238                   0.000134
# 1                        2.508228                   0.016541
# 2                        0.000000                   0.000000
# 3                        0.000000                   0.000000
# 4                        4.499760                   2.991381
# ...                           ...                        ...
# 44743                    1.469480                   0.000036
# 44744                    0.728360                   0.000319
# 44745                    0.640385                   0.000454
# 44746                    0.941695                   0.001759
# 44747                    0.211180                   0.000038
#
#        Max Inter-Packet Interval     Label
# 0                       9.805283  trickbot
# 1                       9.972808  trickbot
# 2                       0.000000  trickbot
# 3                       0.000000  trickbot
# 4                       6.008138  trickbot
# ...                          ...       ...
# 44743                   6.931239  trickbot
# 44744                   1.868169  trickbot
# 44745                   1.881724  trickbot
# 44746                   1.881630  trickbot
# 44747                   0.629971  trickbot
#
# [44748 rows x 20 columns]

# %%
engineering_df["Duration"] = engineering_df["Duration"].replace(0.000, 0.000001)


engineering_df["Bytes per Packet"] = engineering_df.apply(
    lambda row: row["Bytes"] / row["Packets"] if row["Packets"] > 0 else 0, axis=1
)

# Calculate 'Packets per Second' and 'Bytes per Second' if duration is not zero
engineering_df["Packets per Second"] = engineering_df.apply(
    lambda row: row["Packets"] / row["Duration"] if row["Duration"] > 0 else 0, axis=1
)

engineering_df["Bytes per Second"] = engineering_df.apply(
    lambda row: row["Bytes"] / row["Duration"] if row["Duration"] > 0 else 0, axis=1
)

# %%
def clean_port(port):
    try:
        # Attempt to convert port to integer
        return int(port)
    except ValueError:
        # If conversion fails, return 0
        return 0


# Clean the 'Destination Port' data
engineering_df["Destination Port"] = engineering_df["Destination Port"].apply(
    clean_port
)

engineering_df["Source Port"] = engineering_df["Source Port"].apply(clean_port)


def is_encrypted_protocol(port):
    encrypted_ports = {443, 22, 993, 995, 465, 587, 636, 989, 990, 992, 1194, 500}
    return 1 if port in encrypted_ports else 0


def is_common_port(port):
    common_ports = {80, 443, 21, 22, 25, 110, 143, 3306, 3389, 5900, 53, 23}
    return 1 if (port in common_ports) else 0


engineering_df["Destination Port"] = engineering_df["Destination Port"].astype(int)
engineering_df["Source Port"] = engineering_df["Source Port"].astype(int)


# Apply the encryption check
engineering_df["Is Encrypted Traffic"] = engineering_df["Destination Port"].apply(
    is_encrypted_protocol
)

engineering_df["Is Encrypted Traffic"] = engineering_df["Source Port"].apply(
    is_encrypted_protocol
)

# Apply the common port check
engineering_df["Common Port Usage"] = engineering_df["Destination Port"].apply(
    is_common_port
)

engineering_df["Common Port Usage"] = engineering_df["Source Port"].apply(
    is_common_port
)

# %% [markdown]
# ## Additional Shit

# %%
def feature_engineering(df):
    # Flags Count (specific flags)
    df['flags_count'] = df['Flags'].apply(lambda x: x.split(',') if x else [])
    df['syn_count'] = df['flags_count'].apply(lambda x: x.count('SYN'))
    df['ack_count'] = df['flags_count'].apply(lambda x: x.count('ACK'))
    df['fin_count'] = df['flags_count'].apply(lambda x: x.count('FIN'))
    df['flags_count'] = df['flags_count'].apply(lambda x: len(x))


    # Is HTTP Protocol
    df['is_http'] = (df['Protocol'] == 'HTTP').astype(int)

    # Internal IP Check
    df['is_internal_ip'] = df['Source IP'].apply(lambda x: 1 if x.startswith('10.') or x.startswith('172.') or x.startswith('192.') else 0)

    # Packet Direction (assumed local device IP is 10.0.2.102 for example)
    local_device_ip = '192.168.1.110'
    df['direction'] = df['Destination IP'].apply(lambda x: 'inbound' if x == local_device_ip else 'outbound')

    # Short Duration Check
    threshold_duration = 0.1  # Example threshold
    df['short_duration'] = (df['Duration'] < threshold_duration).astype(int)

    # Single Packet Check
    df['single_packet'] = (df['Packets'] == 1).astype(int)

    return df

engineering_df = feature_engineering(engineering_df)

# %%
engineering_df.drop(["Destination IP", "Source IP"], axis=1, inplace=True)

# %%
df = engineering_df.copy()


df.to_csv(r"../../data/processed/trickbot_static.csv", index=False)

# %%
df
# Out:
#         Duration  Source Port  Destination Port         Protocol  \
# 0      10.032950        49158                80              TCP
# 1      10.032912           80             49158              TCP
# 2       0.000001        49158                80             HTTP
# 3       0.000001           80             49158  DATA-TEXT-LINES
# 4       8.999519        49159               443              TCP
# ...          ...          ...               ...              ...
# 44743  19.103234          443             60419              TLS
# 44744   2.913438        60420               443              TCP
# 44745   1.921156          443             60420              TCP
# 44746   1.883389        60420               443              TLS
# 44747   0.844718          443             60420              TLS
#
#                  Flags  Packets  Bytes  Mean Payload Size  Std Payload Size  \
# 0          FIN,SYN,ACK        5    182          36.400000          4.800000
# 1      FIN,SYN,RST,ACK        5    206          41.200000          2.400000
# 2              PSH,ACK        1    123         123.000000          0.000000
# 3              PSH,ACK        1    260         260.000000          0.000000
# 4                  SYN        3    134          44.666667          1.885618
# ...                ...      ...    ...                ...               ...
# 44743          PSH,ACK       14  12750         910.714286        583.210257
# 44744          SYN,ACK        5    182          36.400000          4.800000
# 44745          SYN,ACK        4    148          37.000000          5.196152
# 44746          PSH,ACK        3    619         206.333333         62.887907
# 44747          PSH,ACK        5   2638         527.600000        529.438419
#
#        Min Payload Size  ...  Common Port Usage  flags_count  syn_count  \
# 0                    34  ...                  0            3          1
# 1                    40  ...                  1            4          1
# 2                   123  ...                  0            2          0
# 3                   260  ...                  1            2          0
# 4                    42  ...                  0            1          1
# ...                 ...  ...                ...          ...        ...
# 44743                93  ...                  1            2          0
# 44744                34  ...                  0            2          1
# 44745                34  ...                  1            2          1
# 44746               156  ...                  0            2          0
# 44747                93  ...                  1            2          0
#
#        ack_count  fin_count  is_http  is_internal_ip direction  \
# 0              1          1        0               1  outbound
# 1              1          1        0               0  outbound
# 2              1          0        1               1  outbound
# 3              1          0        0               0  outbound
# 4              0          0        0               1  outbound
# ...          ...        ...      ...             ...       ...
# 44743          1          0        0               0  outbound
# 44744          1          0        0               1  outbound
# 44745          1          0        0               0  outbound
# 44746          1          0        0               1  outbound
# 44747          1          0        0               0  outbound
#
#        short_duration  single_packet
# 0                   0              0
# 1                   0              0
# 2                   1              1
# 3                   1              1
# 4                   0              0
# ...               ...            ...
# 44743               0              0
# 44744               0              0
# 44745               0              0
# 44746               0              0
# 44747               0              0
#
# [44748 rows x 32 columns]

# %%
df["Is Encrypted Traffic"].value_counts()
# Out:
# Is Encrypted Traffic
# 0    22999
# 1    21749
# Name: count, dtype: int64

# %%
df["Label"].isna().value_counts()
# Out:
# Label
# False    44748
# Name: count, dtype: int64
